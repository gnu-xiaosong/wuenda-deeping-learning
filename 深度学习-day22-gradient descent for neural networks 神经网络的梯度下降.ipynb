# %% [markdown]
# # Gradient Descnet for Neural Networks-神经网络的梯度下降

# %% [markdown]
# * 符号说明 symbol instruction:

# %% [markdown]
# $n_{x}:represent each neyral network's layer never cell for amount 代表每层神经元的数量，x代表神经层数$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Gradient Descent for Neural Network-神经网络的梯度下降

# %% [markdown]
# > 以单层神经网络为例

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Formulas for computing derivations-计算导数公式

# %% [markdown]
# * Forward propation-正向传播 and Back propation 反向传播:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Training example with vactorized to back propation  -训练样本向量化后的反向传播算法

# %% [markdown]
# ![image.png](attachment:image.png)
