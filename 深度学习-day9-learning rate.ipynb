# %% [markdown]
# # Learning Rate-学习率$\alpha$

# %% [markdown]
# > 如果梯度下降算法正常工作的话，每次迭代$J(\theta)$都应该下降

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Learning rate--$\alpha$ :

# %% [markdown]
# ![image.png](attachment:image.png)
