# %% [markdown]
# # Bais and Variance-偏差和方差-优化算法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hight Bias and Variance calssify 高方差和高偏差类别

# %% [markdown]
# * Hight Bias -高偏差

# %% [markdown]
# * Hight Variance-高方差（过拟合）

# %% [markdown]
# * Hight Bias and Hight Variance-高偏差和高方差

# %% [markdown]
# * Low Bias and Low Variance-低偏差和低方差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Optime Error -最优误差接近0%

# %% [markdown]
# 算法的高低偏差和方差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## easy to matching error‘s example 容易拟合错误的样本

# %% [markdown]
# ![image.png](attachment:image.png)
