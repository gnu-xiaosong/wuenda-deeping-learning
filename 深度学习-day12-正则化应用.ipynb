# %% [markdown]
# # Linear Regression Regularization-线性回归的正则化

# %% [markdown]
# * 参数更新公式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * gradient descent 梯度下降法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Normal equation 正则化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Logistic Regression 逻辑回归的正则化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Gradient Dscent -梯度下降法

# %% [markdown]
# ![image.png](attachment:image.png)
