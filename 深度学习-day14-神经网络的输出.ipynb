# %% [markdown]
# # Neural Network's output - 神经网络的输出

# %% [markdown]
# * Nerual Network's  example:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * matrix expression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Nerual Networks's learnig

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > summary(总结):$权重w和偏置b$的matrix的row（行数）等于该层神经网络的神经元数目，其中weight权重的column列数等于上层输入的$a^{[i]}$特征数量
#
# > n:  Nerual Network's Layout(神经网络的层数，默认从0层开始)

# %% [markdown]
# * 神经元|：

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
