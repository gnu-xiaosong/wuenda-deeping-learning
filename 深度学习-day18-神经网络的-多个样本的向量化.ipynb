# %% [markdown]
# # mutiple trannigs example to natrix -多个样本的向量化

# %% [markdown]
# * 首先对比single Training example 单个训练样本的时候

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 在single Training example 基础上拓展

# %% [markdown]
# * 多训练样本遍历循环方法：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Training example to matrix 训练样本向量化

# %% [markdown]
# horizatal stack 在横向进行堆叠

# %% [markdown]
# > 参数：
#
# > i: Training example 训练样本的数量
#
# > n: Layer of Neural Network's deeps 神经网络的层数
#
# > X: Training Example matrix 训练样本向量化后的大矩阵
#
# > A: a多训练样本的大矩阵
#
# > Z: z多训练样本的大矩阵

# %% [markdown]
# ![image.png](attachment:image.png)
