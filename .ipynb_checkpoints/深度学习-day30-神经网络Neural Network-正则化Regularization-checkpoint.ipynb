# %% [markdown]
# # Regularization-正则化

# %% [markdown]
# ## That is you have a hight variance problem-存在高方差

# %% [markdown]
# * 正则化-Regularization

# %% [markdown]
# * 增加数据集-Add Dataset

# %% [markdown]
# ## Logistic Regression-逻辑回归

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Neural Network-神经网络

# %% [markdown]
# ![image.png](attachment:image.png)
