# %% [markdown]
# # Training dev testDateset 训练 验证 测试集

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 数据data 划分标准

# %% [markdown]
# * 训练集 training Dataset: using to training model parameter 用于训练模型参数

# %% [markdown]
# * 验证集 verification Dataset：用于评估算法效果

# %% [markdown]
# * 测试集 testDataset：using to evalute model用于评估模型

# %% [markdown]
# # Dataset to divide 数据集的划分

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Dataset 获取 不匹配分布获取数据集

# %% [markdown]
# ![image.png](attachment:image.png)
