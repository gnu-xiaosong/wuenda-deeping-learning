# %% [markdown]
# # Building block of deep Neural Networks - 搭建深层次的神经网络块

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 单层

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Forward and Back Function

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
