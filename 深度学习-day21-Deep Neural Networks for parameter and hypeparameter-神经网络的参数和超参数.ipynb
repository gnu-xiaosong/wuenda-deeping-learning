# %% [markdown]
# # Parameter and Hypeparameter-参数和超参数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 深度学习依赖于经验的过程的,需要我们不断实验系统的结果，找到的最佳的hypeparameter。因为系统所处的环境都在不断变化之中，比如电脑性能提升等，可能其过段时间的实验结果会不一样
