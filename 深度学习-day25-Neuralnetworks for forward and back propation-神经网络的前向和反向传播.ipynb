# %% [markdown]
# # 前向传播和反向传播

# %% [markdown]
# ## Forwards propation for layer $l$-对于有$l$层的神经网络的前向传播

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Back Propation for layer $l$:反向传播

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Summary:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 公式总结

# %% [markdown]
# ![image.png](attachment:image.png)
