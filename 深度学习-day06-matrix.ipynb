# %% [markdown]
# # matrix

# %% [markdown]
# matrix相乘的原理是矩阵与向量相乘

# %% [markdown]
# example:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 矩阵与矩阵相乘原理是矩阵与向量相乘

# %% [markdown]
# application：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 矩阵乘法的特性：

# %% [markdown]
# $AB != BA$

# %% [markdown]
# 有分配，无交换

# %% [markdown]
# 单位矩阵有交换律

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 没有逆矩阵的矩阵，可以看成近似为0，也叫奇异矩阵或退化矩阵
