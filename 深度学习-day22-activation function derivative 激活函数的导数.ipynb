# %% [markdown]
# # activation function derivative 激活函数的导数

# %% [markdown]
# # activation function derivative 激活函数的导数

# %% [markdown]
# ##  演算

# %% [markdown]
# * sigmod derivative ：sigmod 导数的推导

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# * tanh activation function:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * ReLu activation and leaky ReLu:

# %% [markdown]
# ![image.png](attachment:image.png)
