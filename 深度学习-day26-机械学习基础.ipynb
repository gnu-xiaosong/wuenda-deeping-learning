# %% [markdown]
# # Machin Learning Knowledge for Basic-机械学习基础

# %% [markdown]
# # Bias and Variance to Control-偏差与方差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
